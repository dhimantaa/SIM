# %%
import sim
symbol = 'BOM500003'

# %%
df, param = sim.technical.macd.Macd(symbol=symbol).simulation(startDate='20181201', endDate='20190215')

# %%
# %matplotlib notebook
sim.plotter.Plotter(data=df,symbol=symbol, param=param).plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# BOM500003

# %%
df, param = sim.technical.rsi.Rsi(symbol=symbol).simulation(startDate='20131201', endDate='20190212')

# %%
sim.plotter.Plotter(data=df,symbol=symbol, param=param).plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# BOM500003
